# %% [markdown]
# # Importing all the nessecary library and the data set

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("House_Rent_Dataset.csv")

# %% [markdown]
# # Understading the Dataset

# %%
df.head()
# Out:
#     Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1  2022-05-13    2  20000   800       1 out of 3   Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3  2022-07-04    2  10000   800       1 out of 2   Super Area
# 4  2022-05-09    2   7500   850       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner
# ...

# %%
df.tail()
# Out:
#        Posted On  BHK   Rent  Size         Floor    Area Type  \
# 4741  2022-05-18    2  15000  1000    3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000    1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750    3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500  23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000    4 out of 5  Carpet Area
#
#              Area Locality       City Furnishing Status  Tenant Preferred  \
# 4741          Bandam Kommu  Hyderabad    Semi-Furnished  Bachelors/Family
# 4742  Manikonda, Hyderabad  Hyderabad    Semi-Furnished  Bachelors/Family
# 4743  Himayath Nagar, NH 7  Hyderabad    Semi-Furnished  Bachelors/Family
# 4744            Gachibowli  Hyderabad    Semi-Furnished            Family
# 4745       Suchitra Circle  Hyderabad       Unfurnished         Bachelors
#
#       Bathroom Point of Contact
# 4741         2    Contact Owner
# 4742         3    Contact Owner
# 4743         3    Contact Agent
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   object
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   object
#  5   Area Type          4746 non-null   object
#  6   Area Locality      4746 non-null   object
#  7   City               4746 non-null   object
#  8   Furnishing Status  4746 non-null   object
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   object
# dtypes: int64(4), object(8)
# memory usage: 296.7+ KB

# %%
df.describe()
# Out:
#                BHK          Rent         Size     Bathroom
# count  4746.000000  4.746000e+03  4746.000000  4746.000000
# mean      2.083860  3.499345e+04   967.490729     1.965866
# std       0.832256  7.810641e+04   634.202328     0.884532
# min       1.000000  1.200000e+03    10.000000     1.000000
# 25%       2.000000  1.000000e+04   550.000000     1.000000
# 50%       2.000000  1.600000e+04   850.000000     2.000000
# 75%       3.000000  3.300000e+04  1200.000000     2.000000
# max       6.000000  3.500000e+06  8000.000000    10.000000

# %%
df.shape
# Out:
# (4746, 12)

# %%
df["Floor"].value_counts()
# Out:
# 1 out of 2         379
# Ground out of 2    350
# 2 out of 3         312
# 2 out of 4         308
# 1 out of 3         293
#                   ...
# Ground out of 9      1
# 27 out of 45         1
# 65 out of 78         1
# 24 out of 33         1
# 6 out of 17          1
# Name: Floor, Length: 480, dtype: int64

# %%
df["Area Locality"].value_counts().head(10)
# Out:
# Bandra West        37
# Gachibowli         29
# Electronic City    24
# Velachery          22
# Miyapur, NH 9      22
# Madipakkam         20
# K R Puram          19
# Chembur            19
# Laxmi Nagar        19
# Kondapur           18
# Name: Area Locality, dtype: int64

# %%
df["City"].value_counts()
# Out:
# Mumbai       972
# Chennai      891
# Bangalore    886
# Hyderabad    868
# Delhi        605
# Kolkata      524
# Name: City, dtype: int64

# %%
df["Tenant Preferred"].value_counts()
# Out:
# Bachelors/Family    3444
# Bachelors            830
# Family               472
# Name: Tenant Preferred, dtype: int64

# %%
df["Furnishing Status"].value_counts()
# Out:
# Semi-Furnished    2251
# Unfurnished       1815
# Furnished          680
# Name: Furnishing Status, dtype: int64

# %% [markdown]
# # Checking for null values

# %%
df.isnull()
# Out:
#       Posted On    BHK   Rent   Size  Floor  Area Type  Area Locality   City  \
# 0         False  False  False  False  False      False          False  False
# 1         False  False  False  False  False      False          False  False
# 2         False  False  False  False  False      False          False  False
# 3         False  False  False  False  False      False          False  False
# 4         False  False  False  False  False      False          False  False
# ...         ...    ...    ...    ...    ...        ...            ...    ...
# 4741      False  False  False  False  False      False          False  False
# 4742      False  False  False  False  False      False          False  False
# 4743      False  False  False  False  False      False          False  False
# 4744      False  False  False  False  False      False          False  False
# 4745      False  False  False  False  False      False          False  False
#
# ...

# %%
df.isnull().sum()
# Out:
# Posted On            0
# BHK                  0
# Rent                 0
# Size                 0
# Floor                0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# dtype: int64

# %% [markdown]
# # As there is no null value present , We'll start with data visualization

# %%
df['City'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='City'>

# %%
plt.figure(figsize=(15,10))
plt.title("Rent in different cities according to area types")
sns.barplot(x=df['City'],y=df['Rent'],hue=df['BHK'])
plt.show()

# %%
df
# Out:
#        Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0     2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1     2022-05-13    2  20000   800       1 out of 3   Super Area
# 2     2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3     2022-07-04    2  10000   800       1 out of 2   Super Area
# 4     2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...          ...  ...    ...   ...              ...          ...
# 4741  2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# ...

# %% [markdown]
# # As its always tough for  Bachelors to get a flat

# %%
plt.figure(figsize=(15,5))
plt.title("Flat avaliable for Bachelors")
sns.barplot(x=df['City'],y=df['Rent'],hue=df['Tenant Preferred'])
plt.show()

# %% [markdown]
# It is seen that cities like mumbai and Bangalore have good chances to get a flat as a bachelors

# %%
   for  Bangalore in City:
        plt.figure(figsize=(15,5))
        plt.title("Flat avaliable for Bachelors")
        sns.barplot(x=df['Area'],y=df['Tenant Preferred'],hue=df['Rent'])
        plt.show()

# %%
df.drop("Posted On")
